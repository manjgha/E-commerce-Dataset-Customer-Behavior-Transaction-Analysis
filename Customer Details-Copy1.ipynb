# %% [markdown]
# # E-commerce Customer Behavior Dataset
#
# ### Dataset Information
# 1. User Activity: Session ID, Time Spent, Pages Visited
# 2. Purchase Behavior: Products Viewed, Added to Cart, Purchased
# 3. Customer Details: Age, Location, Device Type
# 4. Transaction Data: Order Amount, Payment Method, Shipping Time

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

import datetime as dt


import sys 
import warnings
if not sys.warnoptions: 
    warnings.simplefilter('ignore')

pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)

import os
os.chdir(r"D:\OneDrive\Documents\Course\Imarticus Learning\Power BI\W Beyond\Assignment")

# %%
df_customer=pd.read_excel('Ecommerce_Customer_Behavior (1) (1).xlsx')
df_customer.head()
# Out:
#   Session ID  Time Spent (min)  Pages Visited  Products Viewed  Added to Cart  \
# 0    SES5000             56.06              6                8              5
# 1    SES5001             59.63             12                7              1
# 2    SES5002             54.44             13                9              3
# 3    SES5003             21.00             11                1              0
# 4    SES5004             25.16              1               10              8
#
#    Purchased  Age Location Device Type  Order Amount Payment Method  \
# 0          2   60    India     Desktop        399.48    Credit Card
# 1          1   31       UK      Mobile        290.76      Apple Pay
# 2          0   61    India      Mobile          0.00            NaN
# 3          0   35       UK      Mobile          0.00            NaN
# 4          4   21       UK      Tablet       1640.41    Credit Card
#
#    Shipping Time (days)
# 0                    10
# 1                     4
# ...

# %%
df_customer.columns
# Out:
# Index(['Session ID', 'Time Spent (min)', 'Pages Visited', 'Products Viewed',
#        'Added to Cart', 'Purchased', 'Age', 'Location', 'Device Type',
#        'Order Amount', 'Payment Method', 'Shipping Time (days)'],
#       dtype='object')

# %%
df_customer.shape
# Out:
# (1000, 12)

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Session ID            1000 non-null   object
#  1   Time Spent (min)      1000 non-null   float64
#  2   Pages Visited         1000 non-null   int64
#  3   Products Viewed       1000 non-null   int64
#  4   Added to Cart         1000 non-null   int64
#  5   Purchased             1000 non-null   int64
#  6   Age                   1000 non-null   int64
#  7   Location              1000 non-null   object
#  8   Device Type           1000 non-null   object
#  9   Order Amount          1000 non-null   float64
#  10  Payment Method        597 non-null    object
#  11  Shipping Time (days)  1000 non-null   int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 93.9+ KB

# %%
#unique values

cols=df_customer.columns

for i in cols:
    print(f'The number of unique values in {i} are: {df_customer[i].nunique()}. \n')
    print(f'The unique values in {i} are: {df_customer[i].unique()}. \n\n')
# Out:
# The number of unique values in Session ID are: 1000.
#
# The unique values in Session ID are: ['SES5000' 'SES5001' 'SES5002' 'SES5003' 'SES5004' 'SES5005' 'SES5006'
#  'SES5007' 'SES5008' 'SES5009' 'SES5010' 'SES5011' 'SES5012' 'SES5013'
#  'SES5014' 'SES5015' 'SES5016' 'SES5017' 'SES5018' 'SES5019' 'SES5020'
#  'SES5021' 'SES5022' 'SES5023' 'SES5024' 'SES5025' 'SES5026' 'SES5027'
#  'SES5028' 'SES5029' 'SES5030' 'SES5031' 'SES5032' 'SES5033' 'SES5034'
#  'SES5035' 'SES5036' 'SES5037' 'SES5038' 'SES5039' 'SES5040' 'SES5041'
#  'SES5042' 'SES5043' 'SES5044' 'SES5045' 'SES5046' 'SES5047' 'SES5048'
#  'SES5049' 'SES5050' 'SES5051' 'SES5052' 'SES5053' 'SES5054' 'SES5055'
#  'SES5056' 'SES5057' 'SES5058' 'SES5059' 'SES5060' 'SES5061' 'SES5062'
#  'SES5063' 'SES5064' 'SES5065' 'SES5066' 'SES5067' 'SES5068' 'SES5069'
#  'SES5070' 'SES5071' 'SES5072' 'SES5073' 'SES5074' 'SES5075' 'SES5076'
#  'SES5077' 'SES5078' 'SES5079' 'SES5080' 'SES5081' 'SES5082' 'SES5083'
# ...

# %%
df_customer["Payment Method"] = df_customer["Payment Method"].replace({None: "Unknown", np.nan: "Unknown"})
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Session ID            1000 non-null   object
#  1   Time Spent (min)      1000 non-null   float64
#  2   Pages Visited         1000 non-null   int64
#  3   Products Viewed       1000 non-null   int64
#  4   Added to Cart         1000 non-null   int64
#  5   Purchased             1000 non-null   int64
#  6   Age                   1000 non-null   int64
#  7   Location              1000 non-null   object
#  8   Device Type           1000 non-null   object
#  9   Order Amount          1000 non-null   float64
#  10  Payment Method        1000 non-null   object
#  11  Shipping Time (days)  1000 non-null   int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 93.9+ KB

# %%
df_customer["Payment Method"].value_counts()
# Out:
# Payment Method
# Unknown        403
# PayPal         162
# Google Pay     157
# Apple Pay      140
# Credit Card    138
# Name: count, dtype: int64

# %%
df_customer.duplicated().sum()
# Out:
# 0

# %%
#df_customer.to_excel("Customer Details.xlsx", index=False)
